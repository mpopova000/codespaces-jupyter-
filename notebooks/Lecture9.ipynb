# %%
stringdata = """
    "temp": [89,72,63,90,88,76,81],
    "pressure": [9,9,10,9,8,7,6],
    "humidity":[20,33,90,100,88,38,79]
"""
stringdata.split()
# Out:
# ['"temp":',
#  '[89,72,63,90,88,76,81],',
#  '"pressure":',
#  '[9,9,10,9,8,7,6],',
#  '"humidity":[20,33,90,100,88,38,79]']

# %%
' [89,72,63,90,88.76,81],'.replace('"','').strip()
# Out:
# '[89,72,63,90,88.76,81],'

# %%
data_list = [[item.replace('"','').strip() for item in line.split(":")] for line in stringdata.split('\n') if len(line)>0]

# %%
weather = {"temp": [89,72,63,90,88,76,81],
           "pressure": [9,9,10,9,8,7,6]}

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plot

# %%
weather_table=pd.DataFrame(weather)

# %%
weather_table
# Out:
#    temp  pressure
# 0    89         9
# 1    72         9
# 2    63        10
# 3    90         9
# 4    88         8
# 5    76         7
# 6    81         6

# %%
type(weather_table["temp"])
# Out:
# pandas.core.series.Series

# %%
weather_table.info
# Out:
# <bound method DataFrame.info of    temp  pressure
# 0    89         9
# 1    72         9
# 2    63        10
# 3    90         9
# 4    88         8
# 5    76         7
# 6    81         6>

# %%
weather_table["temp"]
# Out:
# 0    89
# 1    72
# 2    63
# 3    90
# 4    88
# 5    76
# 6    81
# Name: temp, dtype: int64

# %%
weather_table.columns
# Out:
# Index(['temp', 'pressure'], dtype='object')

# %%
weather2 = [[89,72,63,90,88,76,81],
    [9,9,10,9,8,7,6],
    [20,33,90,100,88,38,79]]

# %%
weather_table2 = pd.DataFrame(weather2)

# %%
weather_table2
# Out:
#     0   1   2    3   4   5   6
# 0  89  72  63   90  88  76  81
# 1   9   9  10    9   8   7   6
# 2  20  33  90  100  88  38  79

# %%
weather2 = np.array([[89,72,63,90,88,76,81],
    [9,9,10,9,8,7,6],
    [20,33,90,100,88,38,79]]).transpose()

# %%
weather2
# Out:
# array([[ 89,   9,  20],
#        [ 72,   9,  33],
#        [ 63,  10,  90],
#        [ 90,   9, 100],
#        [ 88,   8,  88],
#        [ 76,   7,  38],
#        [ 81,   6,  79]])

# %%
columns = ["temp","pressure","humidity"]

# %%
weather_df = pd.DataFrame(weather2, columns = columns)

# %%
weather_df
# Out:
#    temp  pressure  humidity
# 0    89         9        20
# 1    72         9        33
# 2    63        10        90
# 3    90         9       100
# 4    88         8        88
# 5    76         7        38
# 6    81         6        79

# %%
happy_df = pd.read_csv("https://bit.ly/happy_index2019")

# %%
happy_df
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# 1             1.573                    0.996                         0.592
# 2             1.582                    1.028                         0.603
# 3             1.624                    1.026                         0.591
# 4             1.522                    0.999                         0.557
# ..              ...                      ...                           ...
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 0         0.153                      0.393
# 1         0.252                      0.410
# 2         0.271                      0.341
# 3         0.354                      0.118
# 4         0.322                      0.298
# ..          ...                        ...
# 151       0.217                      0.411
# 152       0.276                      0.147
# 153       0.158                      0.025
# 154       0.235                      0.035
# 155       0.202                      0.091
#
# [156 rows x 9 columns]

# %%
happy_df.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
# 5                    1.052                         0.572       0.263
# 6                    1.009                         0.574       0.267
# 7                    1.026                         0.585       0.330
# 8                    1.039                         0.584       0.285
# 9                    1.016                         0.532       0.244
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298
# 5                      0.343
# 6                      0.373
# 7                      0.380
# 8                      0.308
# 9                      0.226

# %%
happy_df.head(15)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# 5              6       Switzerland  7.480           1.452           1.526
# 6              7            Sweden  7.343           1.387           1.487
# 7              8       New Zealand  7.307           1.303           1.557
# 8              9            Canada  7.278           1.365           1.505
# 9             10           Austria  7.246           1.376           1.475
# 10            11         Australia  7.228           1.372           1.548
# 11            12        Costa Rica  7.167           1.034           1.441
# 12            13            Israel  7.139           1.276           1.455
# 13            14        Luxembourg  7.090           1.609           1.479
# 14            15    United Kingdom  7.054           1.333           1.538
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     0.986                         0.596       0.153
# 1                     0.996                         0.592       0.252
# 2                     1.028                         0.603       0.271
# 3                     1.026                         0.591       0.354
# 4                     0.999                         0.557       0.322
# 5                     1.052                         0.572       0.263
# 6                     1.009                         0.574       0.267
# 7                     1.026                         0.585       0.330
# 8                     1.039                         0.584       0.285
# 9                     1.016                         0.532       0.244
# 10                    1.036                         0.557       0.332
# 11                    0.963                         0.558       0.144
# 12                    1.029                         0.371       0.261
# 13                    1.012                         0.526       0.194
# 14                    0.996                         0.450       0.348
#
#     Perceptions of corruption
# 0                       0.393
# 1                       0.410
# 2                       0.341
# 3                       0.118
# 4                       0.298
# 5                       0.343
# 6                       0.373
# 7                       0.380
# 8                       0.308
# 9                       0.226
# 10                      0.290
# 11                      0.093
# 12                      0.082
# 13                      0.316
# 14                      0.278

# %%
happy_df.head(20)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# 5              6       Switzerland  7.480           1.452           1.526
# 6              7            Sweden  7.343           1.387           1.487
# 7              8       New Zealand  7.307           1.303           1.557
# 8              9            Canada  7.278           1.365           1.505
# 9             10           Austria  7.246           1.376           1.475
# 10            11         Australia  7.228           1.372           1.548
# 11            12        Costa Rica  7.167           1.034           1.441
# 12            13            Israel  7.139           1.276           1.455
# 13            14        Luxembourg  7.090           1.609           1.479
# 14            15    United Kingdom  7.054           1.333           1.538
# 15            16           Ireland  7.021           1.499           1.553
# 16            17           Germany  6.985           1.373           1.454
# 17            18           Belgium  6.923           1.356           1.504
# 18            19     United States  6.892           1.433           1.457
# 19            20    Czech Republic  6.852           1.269           1.487
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     0.986                         0.596       0.153
# 1                     0.996                         0.592       0.252
# 2                     1.028                         0.603       0.271
# 3                     1.026                         0.591       0.354
# 4                     0.999                         0.557       0.322
# 5                     1.052                         0.572       0.263
# 6                     1.009                         0.574       0.267
# 7                     1.026                         0.585       0.330
# 8                     1.039                         0.584       0.285
# 9                     1.016                         0.532       0.244
# 10                    1.036                         0.557       0.332
# 11                    0.963                         0.558       0.144
# 12                    1.029                         0.371       0.261
# 13                    1.012                         0.526       0.194
# 14                    0.996                         0.450       0.348
# 15                    0.999                         0.516       0.298
# 16                    0.987                         0.495       0.261
# 17                    0.986                         0.473       0.160
# 18                    0.874                         0.454       0.280
# 19                    0.920                         0.457       0.046
#
#     Perceptions of corruption
# 0                       0.393
# 1                       0.410
# 2                       0.341
# 3                       0.118
# 4                       0.298
# 5                       0.343
# 6                       0.373
# 7                       0.380
# 8                       0.308
# 9                       0.226
# 10                      0.290
# 11                      0.093
# 12                      0.082
# 13                      0.316
# 14                      0.278
# 15                      0.310
# 16                      0.265
# 17                      0.210
# 18                      0.128
# 19                      0.036

# %%
happy_df["Score"]
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
happy_df[["Country or region","Score"]]
# Out:
#             Country or region  Score
# 0                     Finland  7.769
# 1                     Denmark  7.600
# 2                      Norway  7.554
# 3                     Iceland  7.494
# 4                 Netherlands  7.488
# ..                        ...    ...
# 151                    Rwanda  3.334
# 152                  Tanzania  3.231
# 153               Afghanistan  3.203
# 154  Central African Republic  3.083
# 155               South Sudan  2.853
#
# [156 rows x 2 columns]

# %%
short_df = happy_df[["Country or region","Score"]]

# %%
type(short_df)
# Out:
# pandas.core.frame.DataFrame

# %%
short_df.iloc[18:25,:]
# Out:
#        Country or region  Score
# 18         United States  6.892
# 19        Czech Republic  6.852
# 20  United Arab Emirates  6.825
# 21                 Malta  6.726
# 22                Mexico  6.595
# 23                France  6.592
# 24                Taiwan  6.446

# %%
happy_df.loc[18:25,"Overall rank":"Social support"]
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support
# 18            19         United States  6.892           1.433           1.457
# 19            20        Czech Republic  6.852           1.269           1.487
# 20            21  United Arab Emirates  6.825           1.503           1.310
# 21            22                 Malta  6.726           1.300           1.520
# 22            23                Mexico  6.595           1.070           1.323
# 23            24                France  6.592           1.324           1.472
# 24            25                Taiwan  6.446           1.368           1.430
# 25            26                 Chile  6.444           1.159           1.369

# %%
happy_df.Score
# Out:
# 0      7.769
# 1      7.600
# 2      7.554
# 3      7.494
# 4      7.488
#        ...
# 151    3.334
# 152    3.231
# 153    3.203
# 154    3.083
# 155    2.853
# Name: Score, Length: 156, dtype: float64

# %%
happy_df.loc[(happy_df.Score < 7) & (happy_df.Score > 6.0), 
             "Overall rank":"Country or region"]
# Out:
#     Overall rank     Country or region
# 16            17               Germany
# 17            18               Belgium
# 18            19         United States
# 19            20        Czech Republic
# 20            21  United Arab Emirates
# 21            22                 Malta
# 22            23                Mexico
# 23            24                France
# 24            25                Taiwan
# 25            26                 Chile
# 26            27             Guatemala
# 27            28          Saudi Arabia
# 28            29                 Qatar
# 29            30                 Spain
# 30            31                Panama
# 31            32                Brazil
# 32            33               Uruguay
# 33            34             Singapore
# 34            35           El Salvador
# 35            36                 Italy
# 36            37               Bahrain
# 37            38              Slovakia
# 38            39     Trinidad & Tobago
# 39            40                Poland
# 40            41            Uzbekistan
# 41            42             Lithuania
# 42            43              Colombia
# 43            44              Slovenia
# 44            45             Nicaragua
# 45            46                Kosovo
# 46            47             Argentina
# 47            48               Romania
# 48            49                Cyprus
# 49            50               Ecuador
# 50            51                Kuwait
# 51            52              Thailand

# %%
happy_df.Score.mean()
# Out:
# 5.407096153846155

# %%
happy_df.Score.median()
# Out:
# 5.3795

# %%
happy_df.Score.std()
# Out:
# 1.1131198687956712

# %%
happy_df.Score.count()
# Out:
# 156

# %%
happy_df.Score.count()/2
# Out:
# 78.0

# %%
happy_df["Country or region"][78]
# Out:
# 'Turkey'

# %%
happy_df.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# 25%                   0.547750                      0.308000    0.108750
# 50%                   0.789000                      0.417000    0.177500
# 75%                   0.881750                      0.507250    0.248250
# max                   1.141000                      0.631000    0.566000
#
#        Perceptions of corruption
# count                 156.000000
# mean                    0.110603
# std                     0.094538
# min                     0.000000
# 25%                     0.047000
# 50%                     0.085500
# 75%                     0.141250
# max                     0.453000
